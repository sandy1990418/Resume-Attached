# %% [markdown]
# <a href="https://colab.research.google.com/github/sandy1990418/Deep_learning/blob/master/Stock_ma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
import pandas as pd
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import yfinance as yf
import datetime

# %%
#https://towardsdatascience.com/best-5-free-stock-market-apis-in-2019-ad91dddec984

south = yf.Ticker("1702.TW")
south_price = south.history(period="2y")
south_price
# Out:
#              Open   High    Low  Close  Volume  Dividends  Stock Splits
# Date
# 2018-05-29  55.48  55.84  55.30  55.48  207828        0.0             0
# 2018-05-30  55.30  55.94  55.21  55.75  198715        0.0             0
# 2018-05-31  56.30  56.39  55.84  56.12  377626        0.0             0
# 2018-06-01  56.21  56.21  55.48  55.75  305582        0.0             0
# 2018-06-04  55.75  55.94  55.57  55.84  229605        0.0             0
# ...           ...    ...    ...    ...     ...        ...           ...
# 2020-05-25  44.00  44.50  43.80  44.50  137153        0.0             0
# 2020-05-26  44.75  45.30  44.55  45.25  493513        0.0             0
# 2020-05-27  45.55  45.55  44.60  45.10  245826        0.0             0
# 2020-05-28  45.10  45.10  44.60  44.65  207189        0.0             0
# 2020-05-29  44.60  44.80  44.50  44.50  110009        0.0             0
#
# [488 rows x 7 columns]

# %%
south_price['Close'].plot()

# %%
##MOVING AVERAGE

south_price["SMA1"] = south_price['Close'].rolling(window=50).mean()
south_price["SMA2"] = south_price['Close'].rolling(window=200).mean()


plt.figure(figsize=(10,10))
plt.plot(south_price['SMA1'], 'g--', label="SMA1")
plt.plot(south_price['SMA2'], 'r--', label="SMA2")
plt.plot(south_price['Close'], label="close")
plt.legend()
plt.show()
